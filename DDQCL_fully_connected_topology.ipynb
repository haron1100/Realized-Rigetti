# %%
# %matplotlib inline
import random
import ast
from operator import itemgetter
import numpy as np
from multiprocessing.pool import ThreadPool

from pyquil.quil import Program, Pragma, Program
from pyquil.api import QVMConnection, CompilerConnection, get_devices

# %%
import os

API_KEY = 'nmRPAVunQl19TtQz9eMd11iiIsArtUDTaEnsSV6u'
USER_ID = '221422a5-07ab-4cb2-8d4d-2b3dae3aedc7'

PYQUIL_CONFIG = f"""
[Rigetti Forest]
url: https://api.rigetti.com/qvm
key: {API_KEY}
user_id: {USER_ID}
"""

with open(os.path.expanduser('~/.pyquil_config'), 'w') as f:
    f.write(PYQUIL_CONFIG)

# %%
def all_same(items):
    return all(x == items[0] for x in items)

def tester(bitstring,n=2,m=2):
   # print(np.array(bitstring))
    mySplit = np.split(np.array(bitstring),n)
    for line in mySplit:
        if not all_same(line):
            mySplit = np.transpose(mySplit)
            for col in mySplit:
                if not all_same(col):
                    return False
            return True
    return True

# %%
#This class can be used to optimize a quantum circuit for any target probability distribution. 
class DDQCL():
    def __init__(self, init_depth=6, num_qubits=4):
        self.gate_dict={0:['X', 1], 1:['Y', 1], 2:['H', 1], 3:['Z', 1], 4:['CNOT', 2], 5:['ISWAP', 2]}
        self.init_depth = init_depth
        self.chrom_len = 3
        self.num_gates = len(self.gate_dict)
        self.num_qubits = num_qubits
        
        self.best_gene = []
        self.best_fitness = 0
    
    def program_constructor(self, gene):        
        '''Takes in the gene as a parameter and returns the quantum circuit the gene codes for'''
        program_string=''
        for chrom in gene:
            gate_info = self.gate_dict[chrom[0]]
            program_string+= gate_info[0]+ ''.join([' '+str(qubit) for qubit in chrom[1:gate_info[1]+1]]) + ' \n'
        program_string+='MEASURE 0[0] \nMEASURE 1[1] \nMEASURE 2[2] \nMEASURE 3[3]'
        return program_string
    
    #crossover operation between two parent genes
    def crossover(self, gene1, gene2):
        '''Created a combined gene by splicing the two parent genes together
        and samples from it to create the child gene'''
        child = []
        maxlen = max(len(gene1), len(gene2))
        combined = []
        for k in range(maxlen):
            if k<len(gene1):
                combined.append(gene1[k])
            if k<len(gene2):
                combined.append(gene2[k])

        for chrom in combined:
            prob_sample = random.uniform(0, 1)
            if prob_sample>=0.5:
                child.append(chrom)
        if len(child)==0:
            child.append(gene1[0])
        return child
    
    def breed(self, breed_percent):
        '''Replace bottom breed_percent% of the population with children created
        by performing crossover operation on best performing candidates' genes '''
        number_replace = int(len(self.population_genes)*breed_percent)
        for k in range(number_replace):
            parents = random.sample(self.population_genes[number_replace:], 2)
            child = self.crossover(parents[0], parents[1])
            self.population_genes[k] = child

    def mutate(self, mutation_prob=0.1):
        '''Add noise to each candidate's gene in the population'''
        for i, gene in enumerate(self.population_genes):
            for j, chrom in enumerate(gene):
                for k, genotype in enumerate(chrom):
                    prob_sample = random.uniform(0, 1)
                    if prob_sample<mutation_prob:
                        if k==0:
                            self.population_genes[i][j][k] = random.randint(0, self.num_gates-1)
                        else:
                            self.population_genes[i][j][k] = random.randint(0, self.num_qubits-1)
                            #ensure three unique qubits for operations
                            qubitset = set(self.population_genes[i][j][1:]) 
                            while len(qubitset) != self.chrom_len-1: #or qubitset==set((0, 2)) or qubitset==set((0, 3)) or qubitset==set((1, 3)): 
                                self.population_genes[i][j][k] = random.randint(0, self.num_qubits-1)
                                qubitset = set(self.population_genes[i][j][1:])
                            break
    
    def evaluate_fitness(self, datinput, trials=1000):
        """
        Thin function that takes a program string and returns the F1 score on the Bars and Stripes task
        """
        i, quil_program = datinput
        qvm = QVMConnection()
        results = qvm.run(Program(quil_program), trials=trials)
        results = list(map(tuple, results))

        observed_results = set(results)
        recall = 0
        precision = 0
        for result in sorted(observed_results):
            bitstring = ''.join(reversed(list(map(str, result))))
            failer = tester(list(map(str, result)))
            p_i = results.count(result)/len(results) +0.0001
            if failer:
                recall+=1
                precision += p_i
                
            #print(str(failer) + f'|{bitstring}> state: {p_i} [{results.count(result)}/{len(results)}]')
        recall /= 6
        f1 = (2*precision*recall)/(precision+recall+0.0001)
        #print(f1)
        self.fitnesses[i] = f1
        return f1
        
    def run(self, pop_size=50, gens=5, n_top=5):
        '''Perform the optimization using the rest of the functions defined in this class'''
        #initialize population
        self.population_genes = []
        self.fitnesses = [0]*pop_size
        
        #initialize the population with random genes
        for i in range(pop_size):
            depth = random.randint(3, self.init_depth)
            gene = []
            for j in range(depth):
                chrom = []
                chrom.append(random.randint(0, self.num_gates-1))
                for k in range(self.chrom_len-1):
                    chrom.append(random.randint(0, self.num_qubits-1))
                
                qubitset = set(chrom[1:])
                while len(qubitset) != self.chrom_len-1:# or qubitset==set((0, 2)) or qubitset==set((0, 3)) or qubitset==set((1, 3)): 
                    chrom[random.randint(1, self.chrom_len-1)] = random.randint(0, self.num_qubits-1)
                    qubitset = set(chrom[1:])
                gene.append(chrom)
            self.population_genes.append(gene)
        #for each generation
        for g in range(gens):
            #evaluate fitness of population
            '''for k, gene in enumerate(self.population_genes):
                program_string = self.program_constructor(gene)
                fitness = self.evaluate_fitness(program_string)
                fitnesses[k] = fitness'''
            
            programs = []
            for k, gene in enumerate(self.population_genes):
                program_string = self.program_constructor(gene)
                programs.append(program_string)
            
            with ThreadPool(32) as p:
                results = p.map(self.evaluate_fitness, list(enumerate(programs)))
                p.close()
                p.join()

            #sort population_genes by fitness
            self.population_genes, self.fitnesses = zip(*sorted(list(zip(self.population_genes, self.fitnesses)), key=itemgetter(1)))
            self.population_genes, self.fitnesses = list(self.population_genes), list(self.fitnesses)

            #print generation stats
            print('Generation ', g+1 , ' top ', n_top, ' architectures: ')
            for gene, fitness in zip(self.population_genes[-n_top:], self.fitnesses[-n_top:]):
                print('Gene: ', gene, ' Fitness: ', fitness)
            print()
            '''print('Worst: ', self.population_genes[0], 'Fitness: ', self.fitnesses[0])
            print()'''
            
            with open('Results.txt', 'a+') as f:
                f.write('Gene: '+str(self.population_genes[-1])+' Fitness: '+str(self.fitnesses[-1])+'\n\n')
                
            if self.fitnesses[-1]>self.best_fitness:
                self.best_fitness = self.fitnesses[-1]
                self.best_gene = self.population_genes[-1]
            
            if g!=(gens-1): #no need to breed and mutate on final generation
                
                #breed to replace least fit members of population
                self.breed(breed_percent=0.7)
                
                #mutate all members
                self.mutate(mutation_prob=0.1)
                
                '''for gene, fitness in zip(self.population_genes[-n_top:], self.fitnesses[-n_top:]):
                    print('Gene: ', gene, ' Fitness: ', fitness)
                print()
                print('Worst: ', self.population_genes[0], 'Fitness: ', self.fitnesses[0])'''

        with open('Results.txt', 'a+') as f:
            f.write('Best Gene: '+str(self.best_gene)+' Fitness: '+str(self.best_fitness)+'\n\n')

# %%
learner = DDQCL(init_depth=6)
#gene1 = [[0, 2, 1, 3], [4, 1, 2, 3], [3, 3, 2, 1]]
#gene2 = [[1, 3, 2, 0], [2, 2, 3, 1], [3, 3, 2, 0]]
'''print(learner.program_constructor(gene1))
print(learner.program_constructor(gene2))

child = learner.crossover(gene1, gene2)
print()
print(learner.program_constructor(child))'''

learner.run(pop_size=2000, gens=1000)
# Out:
# Generation  1  top  5  architectures:
# Gene:  [[5, 2, 3], [2, 3, 0], [4, 3, 2], [4, 0, 3]]  Fitness:  0.4999875028118673
# Gene:  [[5, 0, 1], [4, 2, 3], [3, 0, 1], [3, 2, 1], [2, 2, 1], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[0, 3, 1], [2, 2, 3], [4, 2, 3], [0, 2, 1], [3, 0, 3]]  Fitness:  0.4999875028118673
# Gene:  [[1, 2, 1], [2, 1, 2], [0, 2, 3], [4, 1, 0], [4, 3, 0]]  Fitness:  0.4999875028118673
# Gene:  [[5, 0, 3], [2, 3, 2], [2, 0, 1], [2, 1, 3], [4, 0, 2]]  Fitness:  0.5806688302525751
#
# Generation  2  top  5  architectures:
# Gene:  [[4, 3, 2], [2, 2, 0], [1, 1, 0], [2, 0, 2], [2, 3, 2], [2, 1, 0]]  Fitness:  0.5343298893529713
# Gene:  [[2, 0, 3], [1, 2, 0], [2, 1, 0], [2, 3, 0], [4, 3, 2], [2, 2, 3]]  Fitness:  0.5407456044356898
# Gene:  [[2, 2, 1], [3, 0, 3], [2, 1, 0], [2, 0, 1], [2, 3, 2], [3, 1, 0]]  Fitness:  0.5637969411933654
# Gene:  [[2, 2, 0], [0, 3, 2], [2, 0, 2], [4, 0, 1], [2, 3, 2]]  Fitness:  0.5761816891412349
# Gene:  [[5, 0, 3], [2, 3, 0], [2, 0, 1], [2, 1, 3], [4, 0, 2]]  Fitness:  0.5819411184673897
#
# Generation  3  top  5  architectures:
# Gene:  [[2, 3, 2], [2, 0, 2], [4, 1, 0], [2, 1, 0], [1, 0, 3], [4, 2, 0], [2, 2, 3]]  Fitness:  0.535403089990481
# Gene:  [[2, 3, 2], [2, 0, 1], [5, 2, 3], [2, 3, 1], [2, 1, 2], [0, 1, 3]]  Fitness:  0.5460492840008723
# Gene:  [[2, 3, 1], [2, 0, 2], [5, 3, 0], [4, 0, 2], [2, 1, 3]]  Fitness:  0.5556495115906108
# Gene:  [[2, 0, 3], [2, 2, 1], [4, 2, 3], [4, 0, 3], [2, 3, 1], [2, 1, 3], [4, 1, 2], [5, 1, 3], [3, 0, 1]]  Fitness:  0.5565418200187631
# Gene:  [[2, 2, 1], [0, 1, 3], [1, 1, 0], [2, 3, 0], [4, 2, 1], [4, 3, 2]]  Fitness:  0.5977963648061766
#
# Generation  4  top  5  architectures:
# Gene:  [[3, 0, 3], [2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 3], [3, 3, 0], [2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 0], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 1], [2, 3, 1], [2, 2, 1], [2, 1, 3], [1, 3, 2]]  Fitness:  0.5386132826769928
# Gene:  [[2, 1, 0], [2, 0, 1], [4, 1, 3], [3, 2, 1], [2, 2, 3]]  Fitness:  0.5617242875741357
#
# Generation  5  top  5  architectures:
# Gene:  [[1, 3, 1], [2, 1, 2], [2, 2, 3], [2, 3, 1], [2, 0, 1]]  Fitness:  0.5289402073986909
# Gene:  [[5, 2, 1], [5, 2, 0], [0, 1, 3], [5, 3, 1], [2, 1, 0], [2, 0, 2], [2, 3, 0], [2, 2, 0], [0, 1, 2], [3, 1, 0]]  Fitness:  0.528940207398691
# Gene:  [[2, 3, 1], [2, 2, 3], [2, 1, 2], [2, 0, 3]]  Fitness:  0.5311008298450466
# Gene:  [[2, 3, 1], [5, 0, 2], [2, 2, 3], [3, 1, 3], [2, 1, 2], [2, 0, 3]]  Fitness:  0.5513145505902802
# Gene:  [[2, 0, 3], [0, 2, 3], [2, 1, 2], [2, 2, 0], [5, 2, 3], [4, 0, 2], [1, 3, 0]]  Fitness:  0.5742422086238793
#
# Generation  6  top  5  architectures:
# Gene:  [[2, 1, 3], [2, 2, 0], [2, 3, 0], [4, 0, 1], [1, 3, 1], [0, 0, 3], [0, 0, 1], [2, 0, 3]]  Fitness:  0.5364747201287774
# Gene:  [[2, 2, 0], [5, 2, 0], [3, 2, 0], [1, 3, 2], [2, 1, 2], [4, 0, 2], [0, 0, 3], [2, 2, 1], [2, 3, 0]]  Fitness:  0.5439324452209362
# Gene:  [[2, 1, 3], [2, 0, 2], [5, 1, 2], [2, 3, 1], [5, 1, 0], [2, 0, 1]]  Fitness:  0.5449916345384447
# Gene:  [[2, 2, 0], [2, 1, 2], [5, 2, 1], [2, 0, 2], [3, 0, 3], [2, 3, 0]]  Fitness:  0.5575827504146534
# Gene:  [[5, 2, 0], [0, 2, 3], [2, 1, 2], [4, 0, 2], [0, 0, 3], [1, 0, 3], [2, 2, 1], [4, 2, 0], [2, 3, 0]]  Fitness:  0.5863604537179666
#
# Generation  7  top  5  architectures:
# Gene:  [[2, 3, 1], [4, 3, 1], [0, 0, 3], [1, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[3, 3, 0], [0, 1, 3], [0, 0, 1], [1, 0, 3], [0, 0, 3], [2, 2, 1], [4, 2, 1]]  Fitness:  0.4999875028118673
# Gene:  [[1, 3, 1], [1, 0, 2], [2, 2, 1], [1, 0, 3], [4, 2, 1], [0, 1, 3], [4, 0, 3], [3, 0, 3]]  Fitness:  0.4999875028118673
# Gene:  [[4, 3, 2], [5, 3, 1], [5, 1, 0], [1, 0, 1], [1, 2, 3], [0, 2, 0], [1, 2, 1], [2, 1, 2], [4, 1, 3], [3, 2, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [3, 2, 1], [2, 2, 0], [2, 1, 0], [4, 1, 3], [3, 0, 1]]  Fitness:  0.5781112841568737
#
# Generation  8  top  5  architectures:
# Gene:  [[2, 3, 2], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 1], [3, 1, 0], [3, 0, 1], [4, 0, 3], [4, 3, 0], [0, 1, 3], [0, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[5, 0, 2], [1, 3, 0], [2, 0, 1], [3, 1, 2], [2, 2, 3], [0, 1, 2], [2, 3, 1], [2, 1, 2]]  Fitness:  0.5311008298450466
# Gene:  [[2, 0, 3], [2, 2, 3], [1, 3, 1], [2, 1, 0], [1, 0, 2], [2, 3, 0]]  Fitness:  0.5321787627504219
# Gene:  [[4, 3, 2], [2, 2, 0], [2, 3, 1], [1, 0, 3], [2, 0, 3], [2, 1, 2]]  Fitness:  0.5668840008597836
#
# Generation  9  top  5  architectures:
# Gene:  [[0, 0, 3], [2, 0, 3], [4, 0, 2], [5, 2, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 1], [5, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 1], [2, 2, 0], [2, 3, 0], [2, 3, 2], [4, 2, 0], [2, 3, 1], [3, 3, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [1, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  10  top  5  architectures:
# Gene:  [[2, 3, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[3, 2, 0], [2, 1, 2], [1, 3, 0], [2, 3, 1], [2, 2, 0], [2, 0, 1]]  Fitness:  0.5169422406762068
# Gene:  [[2, 1, 2], [1, 3, 0], [2, 3, 1], [2, 2, 0], [2, 0, 1]]  Fitness:  0.5375447832126928
# Gene:  [[3, 2, 0], [1, 3, 2], [2, 3, 1], [2, 2, 0], [2, 0, 1], [4, 3, 1]]  Fitness:  0.5556495115906108
# Gene:  [[2, 3, 1], [2, 2, 0], [2, 0, 1], [4, 3, 1]]  Fitness:  0.5703332856529822
#
# Generation  11  top  5  architectures:
# Gene:  [[2, 3, 1], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[3, 3, 2], [2, 0, 3], [4, 0, 2], [3, 0, 3]]  Fitness:  0.4999875028118673
# Gene:  [[5, 0, 1], [3, 3, 0], [2, 1, 0], [0, 0, 2], [4, 1, 3], [2, 0, 3], [4, 0, 1]]  Fitness:  0.5987644415917843
# Gene:  [[4, 2, 0], [1, 0, 3], [3, 3, 0], [5, 2, 0], [2, 1, 0], [4, 2, 1], [4, 1, 3], [2, 0, 3], [4, 0, 1], [1, 0, 2]]  Fitness:  0.6000479846449136
#
# Generation  12  top  5  architectures:
# Gene:  [[2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 2], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 2, 1], [5, 3, 0], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[3, 3, 2], [2, 0, 3], [2, 3, 2], [2, 1, 2], [5, 2, 0], [3, 0, 1], [2, 0, 1]]  Fitness:  0.5407456044356898
#
# Generation  13  top  5  architectures:
# Gene:  [[2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [0, 0, 3], [3, 2, 3], [4, 0, 2], [4, 1, 2], [5, 1, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 0], [2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[3, 2, 1], [2, 2, 0], [4, 2, 0], [0, 1, 0], [5, 0, 1], [1, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  14  top  5  architectures:
# Gene:  [[2, 0, 2], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 3], [4, 1, 3], [2, 2, 0], [2, 0, 3]]  Fitness:  0.5480936257912558
# Gene:  [[2, 2, 3], [2, 0, 2], [2, 3, 0], [4, 0, 1]]  Fitness:  0.5597099347353154
# Gene:  [[2, 1, 3], [4, 1, 3], [2, 2, 0], [3, 0, 1], [2, 0, 3]]  Fitness:  0.5657216865736077
#
# Generation  15  top  5  architectures:
# Gene:  [[0, 2, 1], [4, 1, 0], [5, 2, 1], [2, 3, 0], [4, 3, 1], [0, 3, 0]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 2], [2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 0], [4, 1, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 0], [4, 1, 0], [1, 0, 3], [1, 2, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [0, 2, 1], [2, 2, 0], [2, 3, 0], [2, 1, 3]]  Fitness:  0.54180943354961
#
# Generation  16  top  5  architectures:
# Gene:  [[2, 3, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 1], [2, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  17  top  5  architectures:
# Gene:  [[2, 2, 3], [4, 2, 0], [4, 3, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 0], [2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 2], [4, 0, 2]]  Fitness:  0.4999875028118673
# Generation  18  top  5  architectures:
# Gene:  [[5, 3, 0], [4, 3, 0], [3, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[1, 3, 2], [1, 3, 2], [2, 0, 1], [2, 1, 0]]  Fitness:  0.3886781441494018
# Gene:  [[2, 1, 0], [2, 0, 3], [5, 3, 0], [5, 3, 0]]  Fitness:  0.39808288694671556
# Gene:  [[3, 2, 3], [2, 0, 1], [2, 1, 0]]  Fitness:  0.40868118689311
#
# Generation  19  top  5  architectures:
# Gene:  [[4, 1, 2], [2, 1, 2], [2, 3, 2], [0, 3, 2]]  Fitness:  0.40001599424207285
# Gene:  [[2, 2, 1], [2, 0, 1]]  Fitness:  0.4009721502848719
# Gene:  [[2, 0, 1], [2, 1, 3]]  Fitness:  0.40128934696963664
# Gene:  [[2, 1, 3], [2, 3, 0]]  Fitness:  0.40317673554861905
# Gene:  [[2, 1, 3], [2, 0, 1]]  Fitness:  0.4095763136589691
#
# Generation  20  top  5  architectures:
# Gene:  [[2, 2, 0], [0, 3, 2], [2, 1, 0], [3, 0, 1], [2, 3, 2], [0, 3, 2]]  Fitness:  0.40984186924710886
# Gene:  [[2, 2, 0], [2, 1, 0], [2, 3, 2], [0, 3, 2]]  Fitness:  0.4274101213647813
# Gene:  [[2, 2, 0], [2, 1, 0], [2, 3, 2]]  Fitness:  0.43389178175232057
# Gene:  [[2, 2, 0], [2, 1, 0], [2, 3, 2], [0, 3, 2]]  Fitness:  0.43453188602442333
# Gene:  [[2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
#
# Generation  21  top  5  architectures:
# Gene:  [[2, 2, 1], [2, 0, 2]]  Fitness:  0.39873036281088037
# Gene:  [[2, 2, 3], [2, 0, 2]]  Fitness:  0.40065419442339145
# Gene:  [[0, 0, 1], [2, 2, 3], [2, 0, 2]]  Fitness:  0.4028640373432493
# Gene:  [[2, 3, 1], [2, 2, 3]]  Fitness:  0.4044201502221873
# Gene:  [[2, 2, 1], [2, 0, 2]]  Fitness:  0.4044201502221873
#
# Generation  22  top  5  architectures:
# Gene:  [[3, 2, 0], [3, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 0, 1], [4, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 2], [3, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 2, 0], [3, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[5, 0, 3], [2, 3, 1], [5, 0, 3], [4, 0, 1]]  Fitness:  0.4999875028118673
#
# Generation  23  top  5  architectures:
# Gene:  [[2, 1, 0], [2, 0, 3], [0, 1, 2]]  Fitness:  0.3941313498712657
# Gene:  [[0, 1, 2], [2, 1, 0], [4, 2, 1], [2, 0, 3]]  Fitness:  0.3993747244378532
# Gene:  [[2, 0, 3], [2, 1, 0]]  Fitness:  0.3993747244378532
# Gene:  [[2, 1, 0], [4, 2, 1], [2, 0, 3], [0, 1, 2]]  Fitness:  0.40065419442339145
# Gene:  [[2, 0, 3], [2, 1, 0]]  Fitness:  0.40747794317695984
#
# Generation  24  top  5  architectures:
# Gene:  [[1, 1, 2], [3, 0, 3], [1, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[1, 1, 2], [4, 2, 0], [3, 0, 3], [1, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[2, 0, 3], [5, 1, 0], [2, 0, 3], [5, 1, 0]]  Fitness:  0.39143175533451646
# Gene:  [[5, 0, 1], [2, 0, 1], [5, 0, 1], [2, 0, 1]]  Fitness:  0.3964504234369301
# Gene:  [[2, 0, 3], [2, 1, 3]]  Fitness:  0.40192147365913694
#
# Generation  25  top  5  architectures:
# Gene:  [[3, 2, 1], [5, 2, 1], [2, 3, 2], [2, 3, 1]]  Fitness:  0.285693881048963
# Gene:  [[4, 1, 3], [4, 0, 1], [4, 1, 3], [4, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[2, 1, 0], [0, 2, 0], [2, 1, 0], [0, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 1, 3], [2, 1, 0], [2, 3, 1]]  Fitness:  0.4028640373432493
# Gene:  [[4, 1, 3], [5, 2, 1], [2, 1, 2], [4, 1, 3]]  Fitness:  0.4999875028118673
#
# Generation  26  top  5  architectures:
# Gene:  [[2, 0, 1], [2, 1, 3]]  Fitness:  0.39479799421093403
# Gene:  [[2, 0, 1], [2, 1, 3]]  Fitness:  0.39808288694671556
# Gene:  [[2, 0, 1], [2, 1, 3], [4, 2, 1], [4, 2, 1]]  Fitness:  0.3993747244378532
# Gene:  [[2, 1, 3], [2, 0, 1]]  Fitness:  0.40192147365913694
# Gene:  [[2, 0, 1], [2, 1, 3]]  Fitness:  0.409873310485579
#
# Generation  27  top  5  architectures:
# Gene:  [[2, 0, 3], [5, 0, 1], [2, 0, 3], [5, 0, 1]]  Fitness:  0.39905293149805365
# Gene:  [[5, 1, 0], [2, 0, 3], [5, 1, 0], [2, 0, 3]]  Fitness:  0.39905293149805365
# Gene:  [[2, 1, 0], [5, 1, 0], [2, 1, 0]]  Fitness:  0.40595801243207313
# Gene:  [[2, 1, 0], [5, 0, 1], [2, 1, 0], [1, 0, 3]]  Fitness:  0.4065681188813916
# Gene:  [[4, 1, 0], [2, 1, 0], [4, 1, 0]]  Fitness:  0.4999875028118673
#
# Generation  28  top  5  architectures:
# Gene:  [[1, 2, 1], [1, 1, 2], [1, 2, 1], [1, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[0, 3, 2], [1, 1, 2], [0, 3, 2], [1, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[4, 0, 2], [0, 3, 2], [4, 0, 2], [0, 3, 2]]  Fitness:  0.285693881048963
# Gene:  [[1, 2, 1], [4, 0, 2], [1, 2, 1]]  Fitness:  0.285693881048963
# Gene:  [[2, 2, 0], [4, 2, 3]]  Fitness:  0.4999875028118673
#
# Generation  29  top  5  architectures:
# Gene:  [[2, 0, 1], [2, 2, 1]]  Fitness:  0.40472917239483086
# Gene:  [[2, 0, 3], [0, 1, 2], [2, 3, 1]]  Fitness:  0.4068721025361331
# Gene:  [[2, 0, 3], [4, 0, 2], [2, 0, 3], [5, 3, 1]]  Fitness:  0.40747794317695984
# Gene:  [[2, 2, 3], [2, 0, 3]]  Fitness:  0.40898025426021095
# Gene:  [[4, 0, 2], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  30  top  5  architectures:
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0]]  Fitness:  0.40747794317695984
# Gene:  [[2, 3, 1], [4, 3, 1], [2, 3, 1]]  Fitness:  0.4077798051166582
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0]]  Fitness:  0.40898025426021095
# Gene:  [[2, 1, 2], [0, 2, 0], [3, 1, 2], [5, 3, 1], [0, 2, 0], [2, 1, 2]]  Fitness:  0.41046525029774483
# Gene:  [[5, 3, 1], [2, 1, 0], [4, 3, 1], [5, 3, 1], [4, 3, 1]]  Fitness:  0.4999875028118673
#
# Generation  31  top  5  architectures:
# Gene:  [[1, 2, 0], [5, 2, 3], [1, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[1, 2, 0], [5, 2, 3], [1, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[1, 2, 0], [5, 2, 3], [1, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[2, 3, 2], [5, 2, 3], [2, 3, 2], [5, 2, 3]]  Fitness:  0.3893716994469624
# Gene:  [[2, 1, 0], [2, 3, 2]]  Fitness:  0.40128934696963664
#
# Generation  32  top  5  architectures:
# Gene:  [[2, 3, 0], [5, 3, 1], [2, 3, 0]]  Fitness:  0.3957918680693773
# Gene:  [[2, 3, 0], [2, 2, 1]]  Fitness:  0.39873036281088037
# Gene:  [[2, 3, 0], [1, 2, 3], [2, 2, 1]]  Fitness:  0.40001599424207285
# Gene:  [[2, 3, 0], [4, 3, 2], [2, 3, 0], [4, 3, 2]]  Fitness:  0.40192147365913694
# Gene:  [[2, 3, 0], [2, 2, 1]]  Fitness:  0.4062634230153462
#
# Generation  33  top  5  architectures:
# Gene:  [[5, 2, 0], [5, 3, 1], [5, 2, 0], [5, 3, 1]]  Fitness:  0.285693881048963
# Gene:  [[0, 3, 0], [1, 0, 2], [0, 3, 0], [1, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0]]  Fitness:  0.39840701556780234
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0], [0, 1, 3], [5, 3, 1]]  Fitness:  0.40128934696963664
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0], [5, 3, 1]]  Fitness:  0.4028640373432493
#
# Generation  34  top  5  architectures:
# Gene:  [[2, 3, 1], [4, 3, 0], [2, 2, 0], [2, 3, 1], [4, 3, 0]]  Fitness:  0.4287183002056203
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 2], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [5, 0, 1], [5, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  35  top  5  architectures:
# Gene:  [[2, 0, 2], [2, 2, 1]]  Fitness:  0.405037467142689
# Gene:  [[2, 0, 1], [2, 2, 1], [2, 0, 1], [2, 0, 1]]  Fitness:  0.4053450370312316
# Gene:  [[2, 2, 0], [2, 0, 1]]  Fitness:  0.4065681188813916
# Gene:  [[4, 3, 0], [5, 2, 1], [4, 3, 0], [0, 3, 0], [2, 2, 1], [5, 2, 1], [2, 2, 1]]  Fitness:  0.4071753764737927
# Gene:  [[2, 2, 1], [2, 1, 3], [2, 0, 2]]  Fitness:  0.4241133118378627
#
# Generation  36  top  5  architectures:
# Gene:  [[4, 1, 3], [3, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[3, 3, 0], [4, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 1, 3], [5, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[5, 0, 2], [4, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[5, 0, 1], [2, 3, 1], [5, 0, 1], [4, 0, 3], [4, 1, 3], [2, 3, 1], [4, 1, 3]]  Fitness:  0.285693881048963
#
# Generation  37  top  5  architectures:
# Gene:  [[2, 0, 3], [2, 2, 0]]  Fitness:  0.4062634230153462
# Gene:  [[2, 0, 3], [5, 1, 0], [2, 0, 3]]  Fitness:  0.4065681188813916
# Gene:  [[2, 0, 3], [5, 1, 0], [2, 0, 3]]  Fitness:  0.4065681188813916
# Gene:  [[2, 3, 2], [2, 2, 0]]  Fitness:  0.40957631365896907
# Gene:  [[2, 1, 2], [2, 0, 3]]  Fitness:  0.4184748222859057
#
# Generation  38  top  5  architectures:
# Gene:  [[4, 3, 2], [3, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[1, 3, 2], [3, 0, 2], [1, 3, 2], [4, 3, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 2], [4, 3, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 2], [4, 3, 2]]  Fitness:  0.285693881048963
# Gene:  [[5, 3, 0], [4, 3, 2]]  Fitness:  0.285693881048963
# Generation  39  top  5  architectures:
# Gene:  [[2, 2, 1], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 3], [2, 1, 0], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 2], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 0]]  Fitness:  0.4999875028118673
#
# Generation  40  top  5  architectures:
# Gene:  [[5, 1, 0], [2, 0, 2], [5, 1, 0], [2, 0, 2]]  Fitness:  0.40411039804716714
# Gene:  [[3, 3, 2], [2, 1, 2], [2, 0, 2], [3, 3, 2]]  Fitness:  0.4044201502221873
# Gene:  [[2, 1, 2], [5, 1, 0], [2, 1, 2]]  Fitness:  0.4044201502221873
# Gene:  [[5, 1, 0], [2, 0, 2], [5, 1, 0], [2, 0, 2]]  Fitness:  0.4065681188813916
# Gene:  [[5, 2, 0], [2, 0, 1], [5, 2, 0], [2, 0, 1]]  Fitness:  0.41222480827196767
#
# Generation  41  top  5  architectures:
# Gene:  [[2, 3, 2], [0, 2, 3], [1, 2, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 3, 2], [2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 1], [2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
#
# Generation  42  top  5  architectures:
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [2, 2, 1], [2, 2, 3], [4, 2, 3]]  Fitness:  0.4999875028118673
#
# Generation  43  top  5  architectures:
# Gene:  [[4, 3, 0], [3, 1, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 1, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 1, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 1, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 1, 0]]  Fitness:  0.285693881048963
#
# Generation  44  top  5  architectures:
# Gene:  [[4, 2, 0], [2, 2, 3], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 3], [4, 2, 0], [5, 2, 0]]  Fitness:  0.4999875028118673
#
# Generation  45  top  5  architectures:
# Gene:  [[2, 1, 3], [2, 0, 3], [5, 2, 0], [1, 2, 3], [5, 2, 0], [2, 3, 0]]  Fitness:  0.4167249825052485
# Gene:  [[2, 3, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 2], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  46  top  5  architectures:
# Gene:  [[5, 1, 2], [4, 2, 3], [5, 1, 2], [4, 2, 3]]  Fitness:  0.285693881048963
# Gene:  [[0, 0, 1], [5, 1, 2], [3, 1, 3], [0, 0, 1], [5, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[5, 1, 2], [5, 0, 3], [3, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 1, 3], [5, 1, 2], [5, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[0, 1, 0], [5, 1, 2], [4, 2, 3], [3, 1, 3], [4, 2, 3], [0, 0, 1]]  Fitness:  0.285693881048963
#
# Generation  47  top  5  architectures:
# Gene:  [[5, 2, 3], [2, 3, 1], [5, 2, 3], [2, 3, 1]]  Fitness:  0.39840701556780234
# Gene:  [[2, 3, 1], [5, 2, 3], [2, 3, 1]]  Fitness:  0.3993747244378532
# Gene:  [[2, 3, 1], [5, 2, 3], [2, 3, 1], [5, 2, 3]]  Fitness:  0.40128934696963664
# Gene:  [[5, 0, 1], [2, 0, 3], [5, 0, 1], [2, 0, 3]]  Fitness:  0.4025505960632105
# Gene:  [[2, 3, 1], [5, 2, 3], [2, 0, 3]]  Fitness:  0.40317673554861905
#
# Generation  48  top  5  architectures:
# Gene:  [[2, 3, 0], [2, 1, 0]]  Fitness:  0.4053450370312316
# Gene:  [[0, 3, 1], [0, 3, 1], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[0, 3, 1], [0, 3, 1], [2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 2], [2, 0, 3], [0, 3, 1], [4, 0, 2], [0, 1, 2]]  Fitness:  0.4999875028118673
#
# Generation  49  top  5  architectures:
# Gene:  [[2, 1, 0], [5, 3, 1], [2, 1, 0], [5, 3, 1]]  Fitness:  0.4044201502221873
# Gene:  [[2, 3, 1], [2, 1, 0]]  Fitness:  0.4044201502221873
# Gene:  [[2, 1, 0], [2, 1, 2], [4, 1, 3], [2, 1, 2], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 3], [2, 1, 2], [4, 1, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 0], [4, 1, 3]]  Fitness:  0.4999875028118673
#
# Generation  50  top  5  architectures:
# Gene:  [[2, 1, 2], [5, 1, 2], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 2], [4, 3, 2], [2, 3, 2], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 1], [4, 0, 1], [2, 0, 3], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 1], [5, 1, 2]]  Fitness:  0.4999875028118673
#
# Generation  51  top  5  architectures:
# Gene:  [[0, 2, 3], [2, 2, 0], [5, 2, 1], [2, 2, 0], [5, 0, 1]]  Fitness:  0.4142473220031038
# Gene:  [[4, 1, 0], [2, 0, 2], [5, 0, 1], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 0], [4, 1, 0], [2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 0], [4, 1, 0], [4, 1, 0], [4, 1, 0], [2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 0], [4, 1, 0], [2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
#
# Generation  52  top  5  architectures:
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3], [4, 2, 3], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[4, 2, 3], [2, 2, 1], [4, 2, 3], [4, 2, 3], [4, 2, 3]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 1], [4, 2, 3]]  Fitness:  0.4999875028118673
#
# Generation  53  top  5  architectures:
# Gene:  [[3, 2, 0], [2, 0, 2], [4, 0, 2], [2, 0, 2], [3, 2, 0], [4, 0, 2]]  Fitness:  0.3977579741118593
# Gene:  [[2, 1, 3], [2, 0, 2]]  Fitness:  0.3977579741118593
# Gene:  [[2, 0, 2], [2, 2, 1]]  Fitness:  0.4009721502848719
# Gene:  [[2, 1, 3], [3, 2, 0], [3, 2, 0], [2, 0, 3]]  Fitness:  0.40317673554861905
# Gene:  [[2, 0, 2], [2, 1, 3]]  Fitness:  0.40898025426021095
#
# Generation  54  top  5  architectures:
# Gene:  [[5, 2, 3], [2, 2, 3], [5, 2, 3], [2, 2, 3]]  Fitness:  0.40128934696963664
# Gene:  [[2, 2, 3], [5, 2, 3], [2, 2, 3], [3, 0, 2], [5, 2, 3]]  Fitness:  0.4028640373432493
# Gene:  [[2, 2, 3], [2, 0, 1]]  Fitness:  0.4053450370312316
# Gene:  [[2, 2, 3], [2, 0, 1]]  Fitness:  0.40808096475241384
# Gene:  [[2, 0, 1], [4, 0, 1]]  Fitness:  0.4999875028118673
#
# Generation  55  top  5  architectures:
# Gene:  [[3, 1, 2], [2, 2, 1], [0, 1, 2], [2, 2, 1], [3, 1, 2], [0, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[4, 0, 1], [3, 1, 2], [3, 1, 2], [3, 2, 3]]  Fitness:  0.285693881048963
# Gene:  [[2, 2, 1], [0, 1, 0], [2, 2, 1], [0, 1, 0]]  Fitness:  0.285693881048963
# Gene:  [[0, 1, 0], [2, 2, 1], [0, 1, 0], [3, 1, 2], [2, 2, 1]]  Fitness:  0.285693881048963
# Gene:  [[4, 2, 3], [2, 2, 1], [4, 2, 3], [2, 2, 1]]  Fitness:  0.40001599424207285
#
# Generation  56  top  5  architectures:
# Gene:  [[2, 3, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 1], [2, 3, 1], [4, 0, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 3, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
# Gene:  [[3, 3, 1], [4, 2, 1], [2, 3, 1], [4, 3, 2]]  Fitness:  0.4999875028118673
#
# Generation  57  top  5  architectures:
# Gene:  [[4, 3, 0], [0, 1, 3], [4, 3, 0], [0, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [0, 1, 3], [4, 3, 0], [0, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[0, 1, 3], [5, 0, 1], [0, 3, 0], [5, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[0, 1, 3], [0, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[2, 3, 2], [4, 3, 0], [2, 3, 2], [0, 1, 3], [4, 3, 0]]  Fitness:  0.39840701556780234
#
# Generation  58  top  5  architectures:
# Gene:  [[4, 0, 3], [4, 0, 3], [4, 1, 3], [4, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 0, 3], [4, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[1, 0, 1], [3, 3, 0], [1, 0, 1], [4, 0, 3], [3, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[2, 1, 3], [4, 1, 3], [2, 1, 3]]  Fitness:  0.3944650802073553
# Gene:  [[2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
#
# Generation  59  top  5  architectures:
# Gene:  [[2, 0, 1], [2, 2, 1]]  Fitness:  0.4053450370312316
# Gene:  [[2, 0, 1], [2, 2, 1], [0, 0, 2], [0, 2, 1]]  Fitness:  0.40565188461387924
# Gene:  [[2, 1, 2], [2, 0, 1]]  Fitness:  0.40808096475241384
# Gene:  [[2, 2, 1], [2, 0, 1]]  Fitness:  0.40927862904782125
# Gene:  [[2, 0, 1], [4, 0, 1]]  Fitness:  0.4999875028118673
# Generation  60  top  5  architectures:
# Gene:  [[4, 3, 1], [5, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 1, 0], [2, 1, 0], [4, 1, 0], [2, 1, 0]]  Fitness:  0.39479799421093403
# Gene:  [[2, 1, 0], [3, 0, 3], [4, 1, 0], [2, 1, 0]]  Fitness:  0.3977579741118593
# Gene:  [[2, 1, 0], [4, 1, 0], [2, 1, 0], [4, 1, 0]]  Fitness:  0.4009721502848719
# Gene:  [[2, 1, 0], [5, 3, 2], [5, 3, 2], [4, 1, 0]]  Fitness:  0.4999875028118673
#
# Generation  61  top  5  architectures:
# Gene:  [[2, 0, 1], [0, 2, 1], [2, 0, 1], [0, 2, 1]]  Fitness:  0.285693881048963
# Gene:  [[0, 2, 1], [2, 0, 1], [0, 2, 1], [2, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[2, 3, 2], [0, 2, 1], [2, 0, 1]]  Fitness:  0.3974322742137349
# Gene:  [[2, 3, 2], [4, 3, 2], [2, 3, 2], [4, 3, 2]]  Fitness:  0.405037467142689
# Gene:  [[2, 0, 1], [4, 0, 2], [2, 0, 1]]  Fitness:  0.40868118689311
#
# Generation  62  top  5  architectures:
# Gene:  [[2, 0, 1], [0, 2, 3], [0, 2, 3], [2, 2, 1]]  Fitness:  0.39379680019640734
# Gene:  [[2, 0, 1], [2, 2, 1]]  Fitness:  0.39808288694671556
# Gene:  [[4, 2, 0], [2, 2, 1], [4, 2, 0], [2, 2, 1]]  Fitness:  0.39905293149805365
# Gene:  [[3, 0, 2], [2, 0, 1], [2, 2, 1], [3, 0, 2]]  Fitness:  0.39905293149805365
# Gene:  [[2, 2, 1], [4, 2, 0], [2, 2, 1], [2, 2, 1], [1, 2, 0], [2, 2, 1]]  Fitness:  0.40565188461387924
#
# Generation  63  top  5  architectures:
# Gene:  [[2, 1, 3], [4, 1, 0], [2, 1, 3]]  Fitness:  0.40957631365896907
# Gene:  [[4, 1, 0], [2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 1, 0], [2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 1, 3], [4, 1, 0]]  Fitness:  0.4999875028118673
# Gene:  [[1, 0, 2], [2, 1, 3], [1, 0, 2], [4, 1, 0]]  Fitness:  0.4999875028118673
#
# Generation  64  top  5  architectures:
# Gene:  [[4, 3, 0], [3, 0, 1], [4, 3, 0], [3, 0, 1]]  Fitness:  0.285693881048963
# Gene:  [[1, 2, 0], [4, 3, 0], [3, 3, 2], [1, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 2, 0], [3, 3, 2], [4, 2, 0], [2, 0, 2], [4, 2, 0], [2, 0, 2], [4, 2, 0], [3, 3, 2]]  Fitness:  0.285693881048963
# Gene:  [[2, 0, 2], [4, 2, 0], [2, 0, 2], [4, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[2, 0, 3], [4, 2, 0], [2, 0, 3]]  Fitness:  0.285693881048963
#
# Generation  65  top  5  architectures:
# Gene:  [[3, 3, 2], [5, 2, 3], [3, 3, 2], [5, 2, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 3, 1], [3, 2, 1], [3, 3, 1], [3, 2, 1]]  Fitness:  0.285693881048963
# Gene:  [[5, 2, 3], [1, 0, 2], [5, 2, 3], [1, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 3, 2], [1, 0, 3], [1, 3, 0], [4, 2, 3], [3, 3, 2], [4, 2, 3], [1, 3, 0], [1, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 2, 3], [1, 3, 0], [4, 2, 3], [1, 3, 0]]  Fitness:  0.285693881048963
#
# Generation  66  top  5  architectures:
# Gene:  [[4, 2, 0], [5, 0, 2], [4, 2, 0], [5, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[0, 2, 1], [3, 0, 2], [0, 2, 1], [3, 0, 2]]  Fitness:  0.285693881048963
# Gene:  [[1, 1, 3], [3, 2, 0], [2, 1, 2], [1, 3, 1], [1, 1, 3], [1, 3, 1], [2, 1, 2], [3, 2, 0]]  Fitness:  0.285693881048963
# Gene:  [[1, 3, 1], [2, 1, 2], [1, 3, 1], [2, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[2, 1, 0], [4, 1, 2], [5, 2, 3]]  Fitness:  0.4999875028118673
#
# Generation  67  top  5  architectures:
# Gene:  [[2, 3, 0], [5, 3, 1], [2, 3, 0]]  Fitness:  0.4028640373432493
# Gene:  [[2, 3, 0], [5, 3, 1], [2, 3, 0], [5, 3, 1]]  Fitness:  0.40411039804716714
# Gene:  [[2, 3, 0], [5, 1, 3], [2, 3, 0], [5, 1, 3]]  Fitness:  0.4044201502221873
# Gene:  [[5, 3, 1], [2, 3, 0], [5, 3, 1], [2, 3, 0]]  Fitness:  0.4053450370312316
# Gene:  [[5, 3, 1], [2, 3, 0], [5, 3, 1], [2, 3, 0]]  Fitness:  0.41046525029774483
#
# Generation  68  top  5  architectures:
# Gene:  [[2, 0, 3], [4, 0, 2], [2, 0, 3]]  Fitness:  0.3967785017604922
# Gene:  [[4, 3, 0], [2, 2, 1], [5, 3, 2], [2, 2, 1], [5, 3, 2]]  Fitness:  0.4009721502848719
# Gene:  [[5, 3, 2], [2, 2, 1], [5, 3, 2], [2, 2, 1]]  Fitness:  0.40348869331859977
# Gene:  [[0, 0, 1], [2, 2, 1], [2, 0, 3]]  Fitness:  0.40898025426021095
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  69  top  5  architectures:
# Gene:  [[2, 3, 0], [2, 2, 0]]  Fitness:  0.3993747244378532
# Gene:  [[2, 2, 3], [4, 3, 0], [2, 3, 0]]  Fitness:  0.4022364090566636
# Gene:  [[2, 3, 1], [2, 2, 3]]  Fitness:  0.4025505960632105
# Gene:  [[2, 2, 3], [2, 3, 1]]  Fitness:  0.40348869331859977
# Gene:  [[2, 2, 3], [2, 3, 1]]  Fitness:  0.40927862904782125
#
# Generation  70  top  5  architectures:
# Gene:  [[2, 0, 1], [5, 0, 1], [2, 0, 1]]  Fitness:  0.40595801243207313
# Gene:  [[5, 0, 1], [2, 0, 1], [5, 0, 1], [2, 0, 1]]  Fitness:  0.40717537647379276
# Gene:  [[5, 1, 0], [2, 0, 1], [5, 1, 0], [2, 0, 1]]  Fitness:  0.40717537647379276
# Gene:  [[2, 0, 1], [0, 3, 1], [5, 0, 1], [0, 3, 1], [2, 0, 1]]  Fitness:  0.40717537647379276
# Gene:  [[2, 0, 1], [5, 0, 1], [2, 0, 1], [5, 0, 1]]  Fitness:  0.40717537647379276
#
# Generation  71  top  5  architectures:
# Gene:  [[4, 0, 3], [3, 1, 2], [4, 0, 3], [3, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[5, 3, 1], [3, 1, 2], [5, 3, 1], [3, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 1, 2], [1, 2, 0], [4, 0, 3], [1, 2, 0], [3, 1, 2]]  Fitness:  0.285693881048963
# Gene:  [[3, 1, 2], [4, 0, 3], [3, 1, 2], [4, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[1, 2, 0], [2, 2, 3], [1, 2, 0], [5, 0, 2], [2, 2, 3]]  Fitness:  0.3964504234369301
#
# Generation  72  top  5  architectures:
# Gene:  [[3, 0, 3], [3, 1, 2], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 1, 2], [3, 0, 3], [3, 1, 2], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[0, 0, 2], [3, 0, 3], [0, 0, 2], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 3], [1, 3, 2], [3, 1, 2], [1, 3, 2], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 3], [3, 1, 2], [3, 0, 3], [3, 1, 2]]  Fitness:  0.285693881048963
#
# Generation  73  top  5  architectures:
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 2], [2, 0, 1], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
# Gene:  [[2, 0, 3], [4, 0, 2]]  Fitness:  0.4999875028118673
#
# Generation  74  top  5  architectures:
# Gene:  [[2, 0, 2], [5, 0, 2], [2, 0, 2]]  Fitness:  0.4037999132799874
# Gene:  [[4, 1, 2], [2, 0, 2], [4, 1, 2], [5, 0, 2], [2, 0, 2]]  Fitness:  0.40595801243207313
# Gene:  [[2, 0, 2], [2, 0, 2], [2, 0, 2], [5, 0, 2], [2, 0, 2]]  Fitness:  0.4083814245323211
# Gene:  [[5, 0, 2], [2, 0, 2], [5, 0, 2], [2, 0, 2]]  Fitness:  0.4083814245323211
# Gene:  [[2, 0, 2], [2, 2, 1]]  Fitness:  0.4083814245323211
#
# Generation  75  top  5  architectures:
# Gene:  [[2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 2, 0], [2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 2, 0], [2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
# Gene:  [[4, 2, 0], [2, 2, 0], [4, 2, 0]]  Fitness:  0.4999875028118673
#
# Generation  76  top  5  architectures:
# Gene:  [[3, 3, 0], [5, 1, 2], [3, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[3, 3, 0], [5, 1, 2], [3, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[2, 3, 2], [4, 3, 2], [2, 3, 2]]  Fitness:  0.39479799421093403
# Gene:  [[2, 3, 2], [4, 3, 2], [2, 3, 2]]  Fitness:  0.39873036281088037
# Gene:  [[2, 2, 1], [2, 0, 3]]  Fitness:  0.4009721502848719
#
# Generation  77  top  5  architectures:
# Gene:  [[3, 2, 3], [3, 0, 2], [3, 2, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 0, 1], [4, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[2, 0, 3], [5, 0, 2], [2, 0, 3], [5, 0, 2]]  Fitness:  0.3957918680693773
# Gene:  [[2, 0, 1], [2, 1, 3]]  Fitness:  0.39808288694671556
# Gene:  [[5, 2, 0], [2, 0, 1], [5, 2, 0], [2, 0, 1]]  Fitness:  0.40065419442339145
#
# Generation  78  top  5  architectures:
# Gene:  [[5, 1, 3], [2, 3, 0], [5, 1, 3], [2, 3, 0], [5, 1, 3]]  Fitness:  0.4009721502848719
# Gene:  [[2, 0, 3], [2, 1, 2]]  Fitness:  0.40160578719344964
# Gene:  [[2, 0, 2], [2, 1, 2]]  Fitness:  0.4065681188813916
# Gene:  [[2, 3, 0], [5, 1, 3], [2, 3, 0]]  Fitness:  0.40808096475241384
# Gene:  [[2, 1, 2], [2, 0, 2], [3, 2, 1]]  Fitness:  0.40927862904782125
#
# Generation  79  top  5  architectures:
# Gene:  [[2, 0, 2], [2, 2, 0]]  Fitness:  0.40717537647379276
# Gene:  [[2, 0, 2], [5, 1, 0], [2, 0, 2]]  Fitness:  0.4077798051166582
# Gene:  [[2, 0, 2], [5, 1, 0], [2, 0, 2]]  Fitness:  0.4077798051166582
# Gene:  [[2, 2, 1], [4, 2, 0], [2, 2, 1]]  Fitness:  0.409873310485579
# Gene:  [[2, 1, 3], [5, 1, 0], [2, 1, 3], [2, 2, 0]]  Fitness:  0.43196274420717856
# Generation  80  top  5  architectures:
# Gene:  [[2, 0, 1], [5, 0, 1], [2, 0, 1], [0, 1, 0]]  Fitness:  0.39873036281088037
# Gene:  [[0, 2, 3], [0, 2, 3], [2, 0, 1], [0, 2, 3], [0, 2, 3], [2, 1, 3]]  Fitness:  0.39969574442531725
# Gene:  [[0, 2, 3], [2, 0, 1], [0, 2, 3], [2, 1, 3]]  Fitness:  0.4022364090566636
# Gene:  [[0, 1, 0], [2, 0, 1], [5, 0, 1], [2, 0, 1]]  Fitness:  0.40348869331859977
# Gene:  [[2, 0, 1], [5, 0, 1], [2, 0, 1], [0, 1, 0]]  Fitness:  0.4044201502221873
#
# Generation  81  top  5  architectures:
# Gene:  [[3, 0, 3], [4, 1, 2], [3, 0, 3], [3, 1, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [3, 0, 3], [4, 3, 0], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [5, 0, 2], [4, 3, 0], [3, 0, 3]]  Fitness:  0.285693881048963
# Gene:  [[3, 0, 3], [4, 3, 0], [5, 0, 2], [4, 3, 0]]  Fitness:  0.285693881048963
# Gene:  [[4, 3, 0], [5, 0, 2], [4, 3, 0], [3, 0, 3]]  Fitness:  0.285693881048963
#
# Generation  82  top  5  architectures:
# Gene:  [[5, 1, 3], [2, 3, 2], [5, 1, 3], [2, 3, 2]]  Fitness:  0.3977579741118593
# Gene:  [[2, 3, 2], [5, 3, 1], [5, 1, 3], [5, 3, 1], [2, 3, 2]]  Fitness:  0.3977579741118593
# Gene:  [[2, 3, 2], [5, 1, 3], [2, 3, 2], [5, 1, 3]]  Fitness:  0.39873036281088037
# Gene:  [[2, 2, 0], [2, 3, 0]]  Fitness:  0.39873036281088037
# Gene:  [[2, 3, 2], [5, 3, 1], [2, 3, 2], [5, 3, 1]]  Fitness:  0.4028640373432493
#
# Generation  83  top  5  architectures:
# Gene:  [[2, 0, 3], [2, 2, 0]]  Fitness:  0.4062634230153462
# Gene:  [[2, 2, 0], [5, 2, 3], [2, 2, 0]]  Fitness:  0.40868118689311
# Gene:  [[5, 2, 3], [2, 2, 0], [5, 2, 3], [2, 2, 0]]  Fitness:  0.40957631365896907
# Gene:  [[2, 2, 0], [5, 2, 3], [2, 2, 0], [1, 3, 1], [5, 2, 3]]  Fitness:  0.40957631365896907
# Gene:  [[2, 2, 0], [2, 0, 2]]  Fitness:  0.409873310485579
#
# Generation  84  top  5  architectures:
# Gene:  [[2, 3, 2], [2, 1, 3]]  Fitness:  0.40192147365913694
# Gene:  [[4, 3, 0], [2, 1, 3], [2, 3, 0]]  Fitness:  0.4028640373432493
# Gene:  [[2, 1, 3], [3, 3, 2], [2, 3, 0]]  Fitness:  0.40317673554861905
# Gene:  [[2, 1, 3], [2, 3, 0]]  Fitness:  0.4037999132799874
# Gene:  [[4, 3, 1], [2, 3, 0], [4, 3, 1]]  Fitness:  0.4999875028118673
#
# Generation  85  top  5  architectures:
# Gene:  [[2, 0, 3], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 2], [2, 0, 2], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[5, 1, 2], [2, 0, 2], [4, 0, 1], [5, 1, 2]]  Fitness:  0.4999875028118673
# Gene:  [[3, 3, 0], [4, 0, 1], [2, 0, 3], [4, 0, 1]]  Fitness:  0.4999875028118673
# Gene:  [[4, 0, 1], [2, 0, 2], [4, 0, 1]]  Fitness:  0.4999875028118673
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3bd3f64bf437> in <module>()
#       9 print(learner.program_constructor(child))'''
#      10
# ---> 11 learner.run(pop_size=2000, gens=1000)
#
# <ipython-input-15-c193b36baa93> in run(self, pop_size, gens, n_top)
#     132
#     133             with ThreadPool(32) as p:
# --> 134                 results = p.map(self.evaluate_fitness, list(enumerate(programs)))
#     135                 p.close()
#     136                 p.join()
#
# ~/.anaconda/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/.anaconda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/.anaconda/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/.anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/.anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
best_program = learner.program_constructor([[1, 0, 2], [2, 3, 0], [3, 1, 2], [2, 1, 3], [5, 0, 1], [5, 1, 0], [4, 1, 2], [0, 1, 2], [2, 0, 2], [3, 3, 0], [4, 3, 1], [4, 0, 1], [1, 1, 0]])
print(best_program)
# Out:
# Y 0
# H 3
# Z 1
# H 1
# ISWAP 0 1
# ISWAP 1 0
# CNOT 1 2
# X 1
# H 0
# Z 3
# CNOT 3 1
# CNOT 0 1
# Y 1
# MEASURE 0[0]
# MEASURE 1[1]
# MEASURE 2[2]
# MEASURE 3[3]

# %%
def execute_alt(quil_program, trials=1000, silent=False, raw=False):
    """
    Thin function that takes a low-level Quil program and returns the
    resulting probability distribution.
    """

    qvm = QVMConnection()
    results = qvm.run(Program(quil_program), trials=trials)
    results = list(map(tuple, results))

    if not silent:
        recall = 0
        precision = 0
        observed_results = set(results)
        for result in sorted(observed_results):
            bitstring = ''.join(reversed(list(map(str, result))))
            failer = tester(list(map(str, result)))
            p_i = results.count(result)/len(results) +0.0001
            if failer:
                recall+=1
                precision += p_i
            print(f'|{bitstring}> state: {results.count(result)/len(results)} [{results.count(result)}/{len(results)}]')
        if raw:
            print(f'Results: {results}')
        recall /= 6
        f1 = (2*precision*recall)/(precision+recall+0.0001)
        print('F1 score: ', f1)

# %%
execute_alt(best_program)
# Out:
# |0000> state: 0.118 [118/1000]
# |1100> state: 0.135 [135/1000]
# |1010> state: 0.132 [132/1000]
# |0110> state: 0.131 [131/1000]
# |1001> state: 0.127 [127/1000]
# |0101> state: 0.104 [104/1000]
# |0011> state: 0.123 [123/1000]
# |1111> state: 0.13 [130/1000]
# F1 score:  0.8522407758076548

# %% [markdown]
# 19 tot 4 double: [[3, 1, 0], [2, 0, 3], [0, 1, 3], [2, 3, 2], [0, 1, 3], [0, 3, 0], [3, 0, 1], [5, 2, 1], [4, 0, 1], [1, 1, 0], [2, 2, 3], [1, 3, 0], [4, 3, 1], [3, 3, 1], [1, 1, 0], [0, 3, 0], [1, 3, 2], [3, 0, 2], [4, 2, 3]]
#
# 13 tot 5 double: [[1, 0, 2], [2, 3, 0], [3, 1, 2], [2, 1, 3], [5, 0, 1], [5, 1, 0], [4, 1, 2], [0, 1, 2], [2, 0, 2], [3, 3, 0], [4, 3, 1], [4, 0, 1], [1, 1, 0]]

# %%
def gate_compiler(rig_Code):
    
    devices = get_devices(as_dict=True)
    agave = devices['8Q-Agave']
    compiler = CompilerConnection(agave)

    job_id = compiler.compile_async(Program(learner.program_constructor(ast.literal_eval(rig_Code.strip()))))
    job = compiler.wait_for_job(job_id)
    
    print('compiled quil', job.compiled_quil())
    return (job.gate_depth(),job.program_fidelity())

# %%
def splitfitness(thestring):
    [genome, score] = thestring.split('Fitness: ')
    genome = genome[6:-1]
    return [genome, score]

with open('Results.txt', 'r') as f:
    txt = f.read()
splittxt = txt.split('\n\n')

# %%
alltogether = list(map(splitfitness, splittxt))
sortedall = sorted(alltogether, key=lambda x:x[1], reverse=True)

# %%
infoline = list(map(gate_compiler, list(zip(*sortedall))[0]))
# Out:
# job SytNvhzQKrpNhzQe is currently compiling
# job shVNiKnLLemgzEnx is currently compiling
# job DJTKGiOlfKGihehT is currently compiling
# job hXJzyBFPPsDwXJxy is currently compiling
# job vRwUoqioifWKGfkJ is currently compiling
# job cEpKKkbpDjTZbgzg is currently compiling
# job SnQIxVUtpidiEcaA is currently compiling
# job ImrvOGCBSHgrMrTH is currently compiling
# job kCVTnaeESQlmuyjd is currently compiling
# job XIPrLRWXkKjCZfHE is currently compiling
# job ivavzMlmmOvZjdnw is currently compiling
# job CZJrmYjqsZFWSkmk is currently compiling
# job nJowiMGHwxHusRPE is currently compiling
# job ASacWTscZifAwzPX is currently compiling
# job IJVTGMbzkCKOsGNZ is currently compiling
# job HfggubrduyQhxIuW is currently compiling
# job BgkGCrFjvhNmYsRL is currently compiling
# job grnQWlNaPAltaCUM is currently compiling
# job GkJHUAlMRNlaIPqu is currently queued for compilation
# job vLtYlUKrWAVbWfRX is currently compiling
# job uQeOjMwcSnCNqOdW is currently compiling
# job LYthGQAxWcDRvCny is currently compiling
# job TkudIxWaQkCCHPOJ is currently compiling
# job SBxnbAZGNRQotMMf is currently compiling
# job lSYFlzQdCxnRBdPf is currently compiling
# job vbjTQmsDwiwcRtqR is currently compiling
# job mlejjaoEHrdMmTIS is currently compiling
# job geKHyLcnWfoDYNmR is currently compiling
# job znycOlGSlDcccPnW is currently compiling
# job jizXGluKZDTDchxa is currently compiling
# job kyuqNFyLaNoyydDh is currently compiling
# job hQoGRqWYXrhgxeMn is currently compiling
# job meLRxxRWzyDufnIA is currently compiling
# job wFyQfIvvOxqJsirC is currently compiling
# job TFaCnFCLaGqNPmdH is currently compiling
# job zNLkyxUBoKfLWJOg is currently compiling
# job nmbGWrLZBwhAejLe is currently compiling
# job KrVOFKJsFzdkJChL is currently compiling
# job JJYHazLUBkcEsRRN is currently compiling
# job jKwEHhkSWLVdBBFr is currently compiling
# job lOhzgVFAcVczymIv is currently compiling
# job yJnsHayWCchTRTIG is currently compiling
# job pAoPmTLAvjGaYsgA is currently compiling
# job KbIowfcapdsHmvSV is currently compiling
# job DZJdJDPNlpGdxYVR is currently compiling
# job zsxwHeSlvwgidYDp is currently compiling
# job mTUsOKKbhuhXaLPJ is currently compiling
# job qHhzybDgalhIMQiT is currently compiling
# job ByrppiFApLOtMhVb is currently compiling
# job smduTbLqwnIEsxvt is currently compiling
# job lsZIedyeetuApmcs is currently compiling
# job AArzvKCHHmfKlpNL is currently compiling
# job phaKypiTHmHKNite is currently compiling
# job ZuSSqSIuuiCtIzfY is currently compiling
# job CXeRypyaKCiwsXXt is currently compiling
# job TYDxuXZTeGJHjEaO is currently compiling
# job SDsQELcFgyLUIPew is currently compiling
# job fnOXHMcdDEPkpcVT is currently compiling
# job IdwQMoAaXhlFQueS is currently compiling
# job TspnLDXibNuZkwlb is currently compiling
# job CuDvaNTuaPteHUdv is currently compiling
# job oZJGoLdXNXNqFSmA is currently compiling
# job OPNemDPRPlZKPiRt is currently compiling
# job LqpeNGKtqSrkzuRu is currently compiling
# job OUPbLCRGJrSyCFLP is currently compiling
# job uIQZvhLulsMhQZpR is currently compiling
# job tKLzIkwHfFztsGdx is currently compiling
# job WoOStNHCKlKphDEp is currently compiling
# job JSYoFEzMIxrnypMg is currently compiling
# job rALlobXVNdYpNQHj is currently compiling
# job rYnDBPTvDPsCsSIk is currently compiling
# job spvIvRIxEadXrdhT is currently compiling
# job OCCdGexTsYHXKhrC is currently compiling
# job BVdphtQYoqVNZmwB is currently compiling
# job PMEXeSSgrhfQYiQV is currently compiling
# job SpWWqyeHmJocvADI is currently compiling
# job QYrNnNxSmGbXbZeF is currently compiling
# job zqNkeuWlAHSZLUQC is currently compiling
# job BtMXzniFtmeERSLP is currently compiling
# job phOOMscqwHKhkdMa is currently compiling
# job fjFuNTDkjqdpZNMX is currently compiling
# job bxqSHgWJArdtipEY is currently compiling
# job OTVboLdaVaWgTvrj is currently compiling
# job ZbbYTpSOXCdWLnws is currently compiling
# job plhHHDqnJuSHWyWa is currently compiling
# job rrVbtGgJILMzgasS is currently compiling
# job NwHlZwkaOGkSbRAw is currently compiling
# job xVAlrOOPMeuSXPGs is currently compiling
# job uxpjomOffJkuBrZD is currently compiling
# job zHFvSClVHbNJJEes is currently compiling
# job xJGMUmFDFTNGkJIV is currently compiling
# job kZBsGaGRCmnFXCCQ is currently compiling
# job mNkkzlKvQltVJTJq is currently compiling
# job TsaDMLYWzHhEPptW is currently compiling
# job XvjAsxItIkKNMeRf is currently compiling
# job RYjAfGTqIVFEqKzM is currently compiling
# job uzERTAuBxrCSQPeC is currently compiling
# job zIMYyWBstdnTYOKD is currently compiling
# job GmQMTNTZnMhgRCub is currently compiling
# job CKMNbtDnkcKlsAux is currently compiling
# job uKMZhGRsWHUgGHoT is currently compiling
# job MmQKsqTFFrsRoXCE is currently compiling
# job OPXJcAGjMPvZYOXL is currently compiling
# job BmDkfIUBfzAopPWi is currently compiling
# job BCdYWGqnFVidaSuJ is currently compiling
# job ARxIzHyQoExurQQC is currently compiling
# job AYDwOurTPMbXTRYp is currently compiling
# job xgyYpWUENmgxBThR is currently compiling
# job bvCWJfzwtyOZbfoV is currently compiling
# job tlZtWnvLsDtLxiHn is currently compiling
# job ejQMXQZjGmvHNSgI is currently compiling
# job kQkPUQDSPaOokQdA is currently compiling
# job ffgKCWMVMXqNTclw is currently compiling
# job HkKSqaPlgqpvZKfC is currently compiling
# job eNfcqwgJOuiRlqNb is currently compiling
# job XOcXsRYNRFatiTxU is currently compiling
# job fXXFMQTXpncJFOKK is currently compiling
# job xYeElhuoLGnuozGE is currently compiling
# job gCbedfxOJDuJFxGp is currently compiling
# job IdASQqcCgbGXILTi is currently compiling
# job QYmtFGMvtbolvVsp is currently compiling
# job zXiaBeamCXcheVps is currently compiling
# job kWxAatPKKIONRGxs is currently compiling
# job HMcHzCixeDssGalL is currently compiling
# job WglRNnmeNHgNjpZa is currently compiling
# job PhXBHVktOxkzhPaj is currently compiling
# job JuqsAPHlbAAZgbqS is currently compiling
# job HHomWtFqiGmDIdRY is currently compiling
# job zYXRZuhzEDImchqq is currently compiling
# job fBlfQIdcVMHoMoxM is currently compiling
# job cvTgGaHmfIREKwRe is currently compiling
# job AegYgteQMoYiVDRr is currently compiling
# job ILZNBSYqBOcMmnoR is currently compiling
# job KoHmfKSBCvNVWJiV is currently compiling
# job VWFxFApLsNbyHySk is currently compiling
# job WjqmJWHPyGKLquGv is currently compiling
# job gPQRqUwGhTUaLbnu is currently compiling
# job feCLGknkQksJbXLY is currently compiling
# job TQtSaVmvGzQYpeYD is currently compiling
# job tANNvAdLOAAVXgzR is currently compiling
# job vhdVdmQHvUVkkiPY is currently compiling
# job NnhLweKklILhrIEF is currently compiling
# job sxvjLXxLTIYlLGEy is currently compiling
# job lmXtyQtRQkPdAWxo is currently compiling
# job faJonfYdwpBVKAEm is currently compiling
# job SHAcHIXMuinRHUuS is currently compiling
# job HDiHuQcitkwlWHch is currently compiling
# job McmmvGvEnbHRtTNt is currently compiling
# job clDfdBjMjuRAjeIn is currently compiling
# job mQjXYZbSStFYDaCB is currently compiling
# job DYiPhjWpgjeCCvfM is currently compiling
# job BuKNPqyXeUBdEGio is currently compiling
# job NyODIfHFkFlcktAR is currently compiling
# job aZxtntTrnPzZTYvS is currently compiling
# job GmsSEhimUtrVnqgF is currently compiling
# job eyrvEVBuBaXOUWsE is currently compiling
# job DccLAaitsZKDhgqt is currently compiling
# job iSqbyhcUbeBAiNkv is currently compiling
# job OuzioZosgQZDHIzZ is currently compiling
# job JkVQGMQULyrYmPca is currently compiling
# job ReUZHPJpQCGyoQAZ is currently compiling
# job TPtcTKVBrJeSfvDM is currently compiling
# job oDPIzadUTOSLLiOi is currently compiling
# job EFBcZzFnYLJhKGPs is currently compiling
# job EHNiISpPZvMzQCSb is currently compiling
# job ZRYsMcHsFFFvOLFe is currently compiling
# job FiZjvumduKZvfgTD is currently compiling
# job RLoDwtbZgQXhZPcO is currently compiling
# job BPedRdXakcGilWTa is currently compiling
# job EDXfEQzjonktwwqd is currently compiling
# job rCqvhOPBNHizLvBX is currently compiling
# job KlngAUZvQzfYDCnM is currently compiling

# %%
allinfo = list(zip(infoline, list(zip(*sortedall))[1]))

# %%
for i, item in enumerate(allinfo):
    print(i, item)
# Out:
# 0 ((100, 0.0), '0.8836300719986605')
# 1 ((125, 0.0), '0.8836300719986605')
# 2 ((236, 0.0), '0.8836300719986605')
# 3 ((144, 0.0), '0.8830066454459151')
# 4 ((174, 0.0), '0.8823825222104262')
# 5 ((122, 0.0), '0.8817577011237211')
# 6 ((160, 0.0), '0.8805059607096882')
# 7 ((189, 0.0), '0.8805059607096882')
# 8 ((75, 0.0), '0.8805059607096882')
# 9 ((91, 0.0), '0.8792514148036085')
# 10 ((92, 0.0), '0.8792514148036085')
# 11 ((171, 0.0), '0.8792514148036085')
# 12 ((263, 0.0), '0.8792514148036085')
# 13 ((182, 0.0), '0.8786230868419578')
# 14 ((211, 0.0), '0.8786230868419578')
# 15 ((153, 0.0), '0.8779940539630897')
# 16 ((127, 0.0), '0.8779940539630897')
# 17 ((143, 0.0), '0.8779940539630897')
# 18 ((233, 0.0), '0.8779940539630897')
# 19 ((137, 0.0), '0.8779940539630897')
# 20 ((173, 0.0), '0.8779940539630897')
# 21 ((214, 0.0), '0.8773643149800752')
# 22 ((135, 0.0), '0.8773643149800752')
# 23 ((241, 0.0), '0.8773643149800752')
# 24 ((251, 0.0), '0.8773643149800752')
# 25 ((88, 0.0), '0.8767338687033189')
# 26 ((123, 0.0), '0.8767338687033189')
# 27 ((143, 0.0), '0.8767338687033189')
# 28 ((131, 0.0), '0.8761027139405518')
# 29 ((388, 0.0), '0.8761027139405518')
# 30 ((187, 0.0), '0.8761027139405518')
# 31 ((168, 0.0), '0.8761027139405518')
# 32 ((98, 0.0), '0.8754708494968235')
# 33 ((158, 0.0), '0.8754708494968235')
# 34 ((97, 0.0), '0.8754708494968235')
# 35 ((229, 0.0), '0.8754708494968235')
# 36 ((105, 0.0), '0.8748382741744951')
# 37 ((214, 0.0), '0.8748382741744951')
# 38 ((180, 0.0), '0.8748382741744951')
# 39 ((263, 0.0), '0.8742049867732312')
# 40 ((280, 0.0), '0.8742049867732312')
# 41 ((254, 0.0), '0.8742049867732312')
# 42 ((80, 0.0), '0.8735709860899927')
# 43 ((173, 0.0), '0.8735709860899927')
# 44 ((299, 0.0), '0.8735709860899927')
# 45 ((194, 0.0), '0.8735709860899927')
# 46 ((112, 0.0), '0.8729362709190286')
# 47 ((204, 0.0), '0.8729362709190286')
# 48 ((263, 0.0), '0.8729362709190286')
# 49 ((177, 0.0), '0.8729362709190286')
# 50 ((253, 0.0), '0.8729362709190286')
# 51 ((252, 0.0), '0.8729362709190286')
# 52 ((113, 0.0), '0.872300840051869')
# 53 ((109, 0.0), '0.8723008400518689')
# 54 ((66, 0.0), '0.8723008400518689')
# 55 ((124, 0.0), '0.8723008400518689')
# 56 ((103, 0.0), '0.8723008400518689')
# 57 ((89, 0.0), '0.8723008400518689')
# 58 ((107, 0.0), '0.8723008400518689')
# 59 ((150, 0.0), '0.8723008400518689')
# 60 ((64, 0.0), '0.8723008400518689')
# 61 ((287, 0.0), '0.8723008400518689')
# 62 ((140, 0.0), '0.8723008400518689')
# 63 ((276, 0.0), '0.8723008400518689')
# 64 ((247, 0.0), '0.8723008400518689')
# 65 ((259, 0.0), '0.8723008400518689')
# 66 ((189, 0.0), '0.8723008400518689')
# 67 ((139, 0.0), '0.871664692277317')
# 68 ((176, 0.0), '0.871664692277317')
# 69 ((190, 0.0), '0.871664692277317')
# 70 ((89, 0.0), '0.8710278263814416')
# 71 ((123, 0.0), '0.8710278263814416')
# 72 ((115, 0.0), '0.8710278263814416')
# 73 ((100, 0.0), '0.8710278263814416')
# 74 ((330, 0.0), '0.8710278263814416')
# 75 ((73, 0.0), '0.8703902411475687')
# 76 ((75, 0.0), '0.8703902411475687')
# 77 ((104, 0.0), '0.8703902411475687')
# 78 ((145, 0.0), '0.8703902411475687')
# 79 ((139, 0.0), '0.869751935356275')
# 80 ((199, 0.0), '0.869751935356275')
# 81 ((136, 0.0), '0.869751935356275')
# 82 ((85, 0.0), '0.8691129077853791')
# 83 ((89, 0.0), '0.8691129077853791')
# 84 ((155, 0.0), '0.8691129077853791')
# 85 ((157, 0.0), '0.8691129077853791')
# 86 ((98, 0.0), '0.8684731572099339')
# 87 ((143, 0.0), '0.8684731572099338')
# 88 ((104, 0.0), '0.8684731572099338')
# 89 ((169, 0.0), '0.8684731572099338')
# 90 ((267, 0.0), '0.8684731572099338')
# 91 ((280, 0.0), '0.8684731572099338')
# 92 ((163, 0.0), '0.8678326824022189')
# 93 ((98, 0.0), '0.8678326824022188')
# 94 ((140, 0.0), '0.8678326824022188')
# 95 ((168, 0.0), '0.8678326824022188')
# 96 ((64, 0.0), '0.8678326824022188')
# 97 ((67, 0.0), '0.8678326824022188')
# 98 ((134, 0.0), '0.8671914821317324')
# 99 ((125, 0.0), '0.8671914821317324')
# 100 ((100, 0.0), '0.8665495551651838')
# 101 ((173, 0.0), '0.8665495551651838')
# 102 ((168, 0.0), '0.8665495551651838')
# 103 ((63, 0.0), '0.8665495551651838')
# 104 ((157, 0.0), '0.8665495551651838')
# 105 ((213, 0.0), '0.8665495551651838')
# 106 ((136, 0.0), '0.8665495551651838')
# 107 ((224, 0.0), '0.8665495551651838')
# 108 ((272, 0.0), '0.8665495551651838')
# 109 ((141, 0.0), '0.8659069002664853')
# 110 ((113, 0.0), '0.8659069002664852')
# 111 ((220, 0.0), '0.8659069002664852')
# 112 ((242, 0.0), '0.8659069002664852')
# 113 ((72, 0.0), '0.8652635161967436')
# 114 ((169, 0.0), '0.8652635161967436')
# 115 ((206, 0.0), '0.8652635161967436')
# 116 ((81, 0.0), '0.8646194017142532')
# 117 ((104, 0.0), '0.8646194017142532')
# 118 ((74, 0.0), '0.8639745555744874')
# 119 ((136, 0.0), '0.8639745555744874')
# 120 ((65, 0.0), '0.8639745555744874')
# 121 ((134, 0.0), '0.8633289765300903\n')
# 122 ((79, 0.0), '0.8633289765300903')
# 123 ((71, 0.0), '0.8633289765300903')
# 124 ((155, 0.0), '0.8626826633308694')
# 125 ((52, 0.0), '0.8626826633308694')
# 126 ((186, 0.0), '0.8620356147237866')
# 127 ((158, 0.0), '0.8620356147237866')
# 128 ((71, 0.0), '0.8607393062596116')
# 129 ((44, 0.0), '0.8607393062596116')
# 130 ((69, 0.0), '0.860090043882145')
# 131 ((33, 4.204944854941015e-05), '0.8574855771976924')
# 132 ((34, 3.2456012853478375e-05), '0.8548691818858418')
# 133 ((39, 0.0), '0.8548691818858418')
# 134 ((106, 0.0), '0.847611914501354')
# 135 ((62, 0.0), '0.8462825171598315')
# 136 ((86, 0.0), '0.8456166676285566')
# 137 ((94, 0.0), '0.8416053744136213')
# 138 ((61, 0.0), '0.8382412731602484')
# 139 ((71, 0.0), '0.8000799760071978')
# 140 ((65, 0.0), '0.8000799760071978')
# 141 ((46, 0.0), '0.8000799760071978')
# 142 ((46, 0.0), '0.8000799760071978')
# 143 ((6, 0.6463079324954535), '0.8000799760071978')
# 144 ((36, 0.0), '0.8000799760071978')
# 145 ((7, 0.487553776947403), '0.8000799760071978')
# 146 ((24, 0.013228677557695365), '0.8000799760071978')
# 147 ((50, 0.0), '0.8000799760071978')
# 148 ((46, 0.0), '0.8000799760071978')
# 149 ((91, 0.0), '0.8000799760071978')
# 150 ((33, 2.808026873683571e-07), '0.8000799760071978')
# 151 ((21, 0.0037547297294302172), '0.8000799760071978')
# 152 ((19, 0.4005414838806055), '0.8000799760071978')
# 153 ((52, 0.0), '0.8000799760071978')
# 154 ((90, 0.0), '0.6072718705826919')
# 155 ((18, 0.05127848056910294), '0.6069632191134863')
# 156 ((48, 0.0), '0.6063444584382871')
# 157 ((14, 0.3269953203980568), '0.6029061457837065')
# 158 ((22, 0.04088498246535883), '0.6019579751671442')
# 159 ((23, 0.01331316209541963), '0.6016409112633423')
# 160 ((6, 0.7543978002388452), '0.6010052656773577')
# 161 ((71, 0.0), '0.6000479846449136')
# 162 ((23, 0.055235332043141294), '0.5974726336123631')
# 163 ((33, 0.0), '0.5971483808603191')
# 164 ((32, 0.0), '0.5958461289801197')
# 165 ((31, 1.688985892607032e-08), '0.5950449826989619')
# 166 ((38, 0.0), '0.5932010545303177')
# 167 ((5, 0.6994168143901721), '0.5913478926137153')
# 168 ((19, 0.17711100221946077), '0.5876135887040402')
# 169 ((5, 0.6994168143901721), '0.583209112642385')
# 170 ((22, 0.08090714708487586), '0.5825756509500352')
# 171 ((21, 0.0401397057660536), '0.5813055124770901')
# 172 ((28, 1.2891339423008707e-06), '0.5750516492127947')
# 173 ((5, 0.6994168143901721), '0.5722927664431444')
# 174 ((3, 0.9279015346255557), '0.5668840008597836')
# 175 ((5, 0.8509779790866987), '0.4999875028118673')

# %%
print(learner.program_constructor(ast.literal_eval(list(zip(*sortedall))[0][131])))
# Out:
# Y 0
# H 3
# Z 1
# H 1
# ISWAP 0 1
# ISWAP 1 0
# CNOT 1 2
# X 1
# H 0
# Z 3
# CNOT 3 1
# CNOT 0 1
# Y 1
# MEASURE 0[0]
# MEASURE 1[1]
# MEASURE 2[2]
# MEASURE 3[3]

# %%
gate_compiler(list(zip(*sortedall))[0][131])
# Out:
# job MXsHaDkSxkurDnWY is currently compiling
# compiled quil PRAGMA EXPECTED_REWIRING "#(0 1 2 3 4 5 6 7)"
# RZ(0.5474521065004054) 0
# RX(pi/2) 0
# RZ(1.4093738333711365) 0
# RX(-pi/2) 0
# RZ(-1.8798809706524215) 0
# RZ(2.0783973416692327) 1
# RX(pi/2) 1
# RZ(0.9128059314825487) 1
# RX(-pi/2) 1
# CZ 0 1
# RZ(pi/2) 0
# RX(-pi) 0
# CZ 0 1
# RZ(-1.0537901828308993) 3
# RX(pi/2) 3
# RZ(1.7571084916166457) 3
# RX(-pi/2) 3
# RZ(0.8653450274961036) 3
# RZ(-2.1376648670344) 0
# RX(pi/2) 0
# RZ(0.5684189363814549) 0
# RX(-pi/2) 0
# RZ(-1.2675983656591754) 0
# RZ(1.2429322797929623) 1
# RX(pi/2) 1
# RZ(1.965569971524997) 1
# RX(-pi/2) 1
# RZ(-pi/2) 2
# RX(pi/2) 2
# CZ 2 1
# RZ(1.674236967864048) 2
# RX(pi/2) 2
# RZ(1.4189783790674746) 2
# RX(-pi/2) 2
# CZ 3 2
# RZ(1.6366529270088535) 2
# RX(pi/2) 2
# RZ(-pi/2) 3
# RX(-pi/2) 3
# CZ 3 2
# RX(-pi/2) 2
# RX(pi/2) 3
# CZ 3 2
# RZ(-0.7241298561798137) 1
# RX(pi/2) 1
# RZ(-0.6542456812873576) 2
# RX(pi/2) 2
# RZ(0.9242262418970197) 2
# RX(-pi/2) 2
# CZ 1 2
# CZ 1 0
# RZ(pi) 0
# RZ(pi) 1
# RX(pi/2) 1
# RZ(1.5707963267948968) 1
# RZ(0.6463506146747173) 2
# RZ(1.4564375502462918) 3
# RX(pi/2) 3
# RZ(1.426995486693993) 3
# RX(-pi/2) 3
# RZ(-3.059616298134544) 3
# PRAGMA CURRENT_REWIRING "#(0 1 3 2 4 5 6 7)"
# PRAGMA EXPECTED_REWIRING "#(0 1 3 2 4 5 6 7)"
# MEASURE 0 [0]
# MEASURE 1 [1]
# MEASURE 2 [3]
# MEASURE 3 [2]
# PRAGMA CURRENT_REWIRING "#(0 1 3 2 4 5 6 7)"
# (33, 4.204944854941015e-05)

# %%
execute_alt("""
Y 0 
H 3 
Z 1 
H 1 
ISWAP 0 1 
ISWAP 1 0 
CNOT 1 2 
X 1 
H 0 
Z 3 
CNOT 3 1 
CNOT 0 1 
Y 1 
MEASURE 0[0] 
MEASURE 1[1] 
MEASURE 2[2] 
MEASURE 3[3]
""")
# Out:
# |0000> state: 0.118 [118/1000]
# |1100> state: 0.122 [122/1000]
# |1010> state: 0.136 [136/1000]
# |0110> state: 0.118 [118/1000]
# |1001> state: 0.134 [134/1000]
# |0101> state: 0.118 [118/1000]
# |0011> state: 0.135 [135/1000]
# |1111> state: 0.119 [119/1000]
# F1 score:  0.8561788757362612
